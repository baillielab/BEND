# %%
import numpy as np
import webdataset as wds
import glob
import os
import torch
import pandas as pd
import yaml

embedding_dims = yaml.safe_load(open('../conf/datadims/embedding_dims.yaml', 'r'))
sequence_lengths = yaml.safe_load(open('../conf/datadims/seq_lengths.yaml', 'r'))

selected_modesl = ['awdlstm', 'nt_transformer_ms', 'nt_transformer_1000g', 'nt_transformer_human_ref', 'hyenadna-tiny-1k', 'hyenadna-large-1m', 'resnetlm', 'dnabert2']
selected_tasks = ['cpg_methylation', 'gene_finding', 'histone_modification','enhancer_annotation', 'chromatin_accessibility']

DATA_DIR = '../data'

requested_memory_df = []

for task in sequence_lengths.keys():

    seq_len = sequence_lengths[task]

    task = task.replace('_length', '')
    if task not in selected_tasks:
        continue

    task_cfg = yaml.safe_load(open(f'../conf/supervised_tasks/{task}.yaml', 'r'))
    task_annotations = pd.read_csv(os.path.join(DATA_DIR, task, f'{task}.bed'), sep='\t', engine='python')
    n_samples = len(task_annotations)
    
    for model in embedding_dims.keys():
        if model not in selected_modesl:
            continue

        embedding_dim = embedding_dims[model]

        embedding_memory = np.float32().itemsize * embedding_dim * seq_len / (1024 ** 3)
        total_memory = embedding_memory * n_samples
        batch_memory = embedding_memory * task_cfg['data']['batch_size']

        requested_memory_df.append({
            'task': task,
            'model': model,
            'embedding_dim': embedding_dim,
            'seq_len': seq_len,
            'n_samples': n_samples,
            'embedding_memory_GB': embedding_memory,
            'total_memory_GB': total_memory,
            'batch_memory_GB': batch_memory,
        })

requested_memory_df = pd.DataFrame(requested_memory_df)
print(len(requested_memory_df), 'total rows')
# Out:
# 40 total rows

# %%
requested_memory_df = requested_memory_df.sort_values(by=['task','total_memory_GB'], ascending=[True, False], ignore_index=True)
requested_memory_df
# Out:
#                        task                     model  embedding_dim  seq_len  \
# 0   chromatin_accessibility         nt_transformer_ms           2560      512
# 1   chromatin_accessibility      nt_transformer_1000g           2560      512
# 2   chromatin_accessibility  nt_transformer_human_ref           1280      512
# 3   chromatin_accessibility                  dnabert2            768      512
# 4   chromatin_accessibility                  resnetlm            256      512
# 5   chromatin_accessibility         hyenadna-large-1m            256      512
# 6   chromatin_accessibility          hyenadna-tiny-1k            128      512
# 7   chromatin_accessibility                   awdlstm             64      512
# 8           cpg_methylation         nt_transformer_ms           2560      512
# 9           cpg_methylation      nt_transformer_1000g           2560      512
# 10          cpg_methylation  nt_transformer_human_ref           1280      512
# 11          cpg_methylation                  dnabert2            768      512
# 12          cpg_methylation                  resnetlm            256      512
# 13          cpg_methylation         hyenadna-large-1m            256      512
# 14          cpg_methylation          hyenadna-tiny-1k            128      512
# 15          cpg_methylation                   awdlstm             64      512
# 16      enhancer_annotation         nt_transformer_ms           2560   100096
# 17      enhancer_annotation      nt_transformer_1000g           2560   100096
# 18      enhancer_annotation  nt_transformer_human_ref           1280   100096
# 19      enhancer_annotation                  dnabert2            768   100096
# 20      enhancer_annotation                  resnetlm            256   100096
# 21      enhancer_annotation         hyenadna-large-1m            256   100096
# 22      enhancer_annotation          hyenadna-tiny-1k            128   100096
# 23      enhancer_annotation                   awdlstm             64   100096
# 24             gene_finding         nt_transformer_ms           2560    12000
# 25             gene_finding      nt_transformer_1000g           2560    12000
# 26             gene_finding  nt_transformer_human_ref           1280    12000
# 27             gene_finding                  dnabert2            768    12000
# 28             gene_finding                  resnetlm            256    12000
# 29             gene_finding         hyenadna-large-1m            256    12000
# 30             gene_finding          hyenadna-tiny-1k            128    12000
# 31             gene_finding                   awdlstm             64    12000
# 32     histone_modification         nt_transformer_ms           2560      512
# 33     histone_modification      nt_transformer_1000g           2560      512
# 34     histone_modification  nt_transformer_human_ref           1280      512
# 35     histone_modification                  dnabert2            768      512
# 36     histone_modification                  resnetlm            256      512
# 37     histone_modification         hyenadna-large-1m            256      512
# 38     histone_modification          hyenadna-tiny-1k            128      512
# 39     histone_modification                   awdlstm             64      512
#
#     n_samples  embedding_memory_GB  total_memory_GB  batch_memory_GB
# 0     2062129             0.004883     10068.989258         1.250000
# 1     2062129             0.004883     10068.989258         1.250000
# 2     2062129             0.002441      5034.494629         0.625000
# 3     2062129             0.001465      3020.696777         0.375000
# 4     2062129             0.000488      1006.898926         0.125000
# 5     2062129             0.000488      1006.898926         0.125000
# 6     2062129             0.000244       503.449463         0.062500
# 7     2062129             0.000122       251.724731         0.031250
# 8      959039             0.004883      4682.807617         1.250000
# 9      959039             0.004883      4682.807617         1.250000
# 10     959039             0.002441      2341.403809         0.625000
# 11     959039             0.001465      1404.842285         0.375000
# 12     959039             0.000488       468.280762         0.125000
# 13     959039             0.000488       468.280762         0.125000
# 14     959039             0.000244       234.140381         0.062500
# 15     959039             0.000122       117.070190         0.031250
# 16        285             0.954590       272.058105         7.636719
# 17        285             0.954590       272.058105         7.636719
# 18        285             0.477295       136.029053         3.818359
# 19        285             0.286377        81.617432         2.291016
# 20        285             0.095459        27.205811         0.763672
# 21        285             0.095459        27.205811         0.763672
# 22        285             0.047729        13.602905         0.381836
# 23        285             0.023865         6.801453         0.190918
# 24       5977             0.114441       684.013367         7.324219
# 25       5977             0.114441       684.013367         7.324219
# 26       5977             0.057220       342.006683         3.662109
# 27       5977             0.034332       205.204010         2.197266
# 28       5977             0.011444        68.401337         0.732422
# 29       5977             0.011444        68.401337         0.732422
# 30       5977             0.005722        34.200668         0.366211
# 31       5977             0.002861        17.100334         0.183105
# 32     625229             0.004883      3052.875977         1.250000
# 33     625229             0.004883      3052.875977         1.250000
# 34     625229             0.002441      1526.437988         0.625000
# 35     625229             0.001465       915.862793         0.375000
# 36     625229             0.000488       305.287598         0.125000
# 37     625229             0.000488       305.287598         0.125000
# 38     625229             0.000244       152.643799         0.062500
# 39     625229             0.000122        76.321899         0.031250

# %%
print('Total memory required for storing embeddings (not compressed): ', requested_memory_df['requested_memory_GB'].sum() / 1024, 'TB')
# Out:
# Total memory required for storing embeddings (not compressed):  56.337196089327335 TB

# %%
requested_memory_df.groupby('task')['requested_memory_GB'].describe()
# Out:
#                          count         mean          std         min  \
# task
# chromatin_accessibility    8.0  3870.267746  4136.122628  251.724731
# cpg_methylation            8.0  1799.954178  1923.595909  117.070190
# enhancer_annotation        8.0   104.572334   111.755575    6.801453
# gene_finding               8.0   262.917638   280.977871   17.100334
# histone_modification       8.0  1173.449203  1254.055306   76.321899
#
#                                 25%          50%          75%           max
# task
# chromatin_accessibility  881.036560  2013.797852  6293.118286  10068.989258
# cpg_methylation          409.745667   936.561523  2926.754761   4682.807617
# enhancer_annotation       23.805084    54.411621   170.036316    272.058105
# gene_finding              59.851170   136.802673   427.508354    684.013367
# histone_modification     267.126648   610.575195  1908.047485   3052.875977

# %%
requested_memory_df.groupby('task')['requested_memory_GB'].sum()
# Out:
# task
# chromatin_accessibility    30962.141968
# cpg_methylation            14399.633423
# enhancer_annotation          836.578674
# gene_finding                2103.341103
# histone_modification        9387.593628
# Name: requested_memory_GB, dtype: float64
