# %%
import numpy as np
import webdataset as wds
import glob
import os
import torch
import pandas as pd
import yaml

embedding_dims = yaml.safe_load(open('../conf/datadims/embedding_dims.yaml', 'r'))
sequence_lengths = yaml.safe_load(open('../conf/datadims/seq_lengths.yaml', 'r'))

DATA_DIR = '../data'

requested_memory_df = []

for task in sequence_lengths.keys():

    n_embeddings = sequence_lengths[task]

    task = task.replace('_length', '')  # remove '_length' suffix if present

    for file in os.listdir(os.path.join(DATA_DIR, task)):
        if not file.startswith(task) or not file.endswith('.bed'):
            continue

        task_annotations = pd.read_csv(os.path.join(DATA_DIR, task, file), sep='\t', engine='python')
        n_samples = len(task_annotations)
        
        for model in embedding_dims.keys():

            embedding_dim = embedding_dims[model]
            
            requested_memory = (np.float32().itemsize * embedding_dim * n_embeddings * n_samples) / (1024 ** 3)
            
            requested_memory_df.append({
                'task': file.split('.')[0],
                'model': model,
                'embedding_dim': embedding_dim,
                'n_embeddings': n_embeddings,
                'n_samples': n_samples,
                'requested_memory_GB': requested_memory
            })

requested_memory_df = pd.DataFrame(requested_memory_df)
print(len(requested_memory_df), 'total rows')
# Out:
# 147 total rows

# %%
selected_models = ['awdlstm', 'nt_transformer_ms', 'nt_transformer_1000g', 'nt_transformer_human_ref', 'hyenadna-tiny-1k', 'hyenadna-large-1m', 'resnetlm', 'dnabert2']

selected_models_df = requested_memory_df[requested_memory_df['model'].isin(selected_models)]
selected_models_df = selected_models_df.sort_values(by=['task','requested_memory_GB'], ascending=[True, False], ignore_index=True)
selected_models_df
# Out:
#                           task                     model  embedding_dim  \
# 0      chromatin_accessibility         nt_transformer_ms           2560
# 1      chromatin_accessibility      nt_transformer_1000g           2560
# 2      chromatin_accessibility  nt_transformer_human_ref           1280
# 3      chromatin_accessibility                  dnabert2            768
# 4      chromatin_accessibility                  resnetlm            256
# 5      chromatin_accessibility         hyenadna-large-1m            256
# 6      chromatin_accessibility          hyenadna-tiny-1k            128
# 7      chromatin_accessibility                   awdlstm             64
# 8              cpg_methylation         nt_transformer_ms           2560
# 9              cpg_methylation      nt_transformer_1000g           2560
# 10             cpg_methylation  nt_transformer_human_ref           1280
# 11             cpg_methylation                  dnabert2            768
# 12             cpg_methylation                  resnetlm            256
# 13             cpg_methylation         hyenadna-large-1m            256
# 14             cpg_methylation          hyenadna-tiny-1k            128
# 15             cpg_methylation                   awdlstm             64
# 16         enhancer_annotation         nt_transformer_ms           2560
# 17         enhancer_annotation      nt_transformer_1000g           2560
# 18         enhancer_annotation  nt_transformer_human_ref           1280
# 19         enhancer_annotation                  dnabert2            768
# 20         enhancer_annotation                  resnetlm            256
# 21         enhancer_annotation         hyenadna-large-1m            256
# 22         enhancer_annotation          hyenadna-tiny-1k            128
# 23         enhancer_annotation                   awdlstm             64
# 24                gene_finding         nt_transformer_ms           2560
# 25                gene_finding      nt_transformer_1000g           2560
# 26                gene_finding  nt_transformer_human_ref           1280
# 27                gene_finding                  dnabert2            768
# 28                gene_finding                  resnetlm            256
# 29                gene_finding         hyenadna-large-1m            256
# 30                gene_finding          hyenadna-tiny-1k            128
# 31                gene_finding                   awdlstm             64
# 32        histone_modification         nt_transformer_ms           2560
# 33        histone_modification      nt_transformer_1000g           2560
# 34        histone_modification  nt_transformer_human_ref           1280
# 35        histone_modification                  dnabert2            768
# 36        histone_modification                  resnetlm            256
# 37        histone_modification         hyenadna-large-1m            256
# 38        histone_modification          hyenadna-tiny-1k            128
# 39        histone_modification                   awdlstm             64
# 40     variant_effects_disease         nt_transformer_ms           2560
# 41     variant_effects_disease      nt_transformer_1000g           2560
# 42     variant_effects_disease  nt_transformer_human_ref           1280
# 43     variant_effects_disease                  dnabert2            768
# 44     variant_effects_disease                  resnetlm            256
# 45     variant_effects_disease         hyenadna-large-1m            256
# 46     variant_effects_disease          hyenadna-tiny-1k            128
# 47     variant_effects_disease                   awdlstm             64
# 48  variant_effects_expression         nt_transformer_ms           2560
# 49  variant_effects_expression      nt_transformer_1000g           2560
# 50  variant_effects_expression  nt_transformer_human_ref           1280
# 51  variant_effects_expression                  dnabert2            768
# 52  variant_effects_expression                  resnetlm            256
# 53  variant_effects_expression         hyenadna-large-1m            256
# 54  variant_effects_expression          hyenadna-tiny-1k            128
# 55  variant_effects_expression                   awdlstm             64
#
#     n_embeddings  n_samples  requested_memory_GB
# 0            512    2062129         10068.989258
# 1            512    2062129         10068.989258
# 2            512    2062129          5034.494629
# 3            512    2062129          3020.696777
# 4            512    2062129          1006.898926
# 5            512    2062129          1006.898926
# 6            512    2062129           503.449463
# 7            512    2062129           251.724731
# 8            512     959039          4682.807617
# 9            512     959039          4682.807617
# 10           512     959039          2341.403809
# 11           512     959039          1404.842285
# 12           512     959039           468.280762
# 13           512     959039           468.280762
# 14           512     959039           234.140381
# 15           512     959039           117.070190
# 16        100096        285           272.058105
# 17        100096        285           272.058105
# 18        100096        285           136.029053
# 19        100096        285            81.617432
# 20        100096        285            27.205811
# 21        100096        285            27.205811
# 22        100096        285            13.602905
# 23        100096        285             6.801453
# 24         12000       5977           684.013367
# 25         12000       5977           684.013367
# 26         12000       5977           342.006683
# 27         12000       5977           205.204010
# 28         12000       5977            68.401337
# 29         12000       5977            68.401337
# 30         12000       5977            34.200668
# 31         12000       5977            17.100334
# 32           512     625229          3052.875977
# 33           512     625229          3052.875977
# 34           512     625229          1526.437988
# 35           512     625229           915.862793
# 36           512     625229           305.287598
# 37           512     625229           305.287598
# 38           512     625229           152.643799
# 39           512     625229            76.321899
# 40             2     295495             5.636120
# 41             2     295495             5.636120
# 42             2     295495             2.818060
# 43             2     295495             1.690836
# 44             2     295495             0.563612
# 45             2     295495             0.563612
# 46             2     295495             0.281806
# 47             2     295495             0.140903
# 48             2     105263             2.007732
# 49             2     105263             2.007732
# 50             2     105263             1.003866
# 51             2     105263             0.602320
# 52             2     105263             0.200773
# 53             2     105263             0.200773
# 54             2     105263             0.100387
# 55             2     105263             0.050193

# %%
print('Total memory required for storing embeddings (not compressed): ', requested_memory_df['requested_memory_GB'].sum() / 1024, 'TB')
# Out:
# Total memory required for storing embeddings (not compressed):  100.42015554659883 TB
